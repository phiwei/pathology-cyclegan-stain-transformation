# %%
import os
import numpy as np
import pandas as pd
from PIL import Image
from tqdm import tqdm

# %%
path_base = '/mnt/ssd2tb/phiwei/acrobat_train_low_res/5/'
folders = ['source', 'target']

# %%
l = list()
for folder in folders:
    path_curr = os.path.join(path_base, folder)
    for filename in tqdm(os.listdir(path_curr)):
        img = Image.open(os.path.join(path_curr, filename))
        d = dict()
        d['filename'] = filename
        d['size_min'] = np.min(img.size)
        d['size_max'] = np.max(img.size)
        l.append(d)
df = pd.DataFrame(l)
df['area'] = df['size_min'] * df['size_max']
df.sort_values('area')
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 821/821 [00:00<00:00, 8740.00it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████| 750/750 [00:00<00:00, 11751.74it/s]
#          filename  size_min  size_max      area
# 46    221_PGR.jpg       896      1280   1146880
# 492   554_PGR.jpg      1232      1920   2365440
# 495    734_ER.jpg      1344      1920   2580480
# 687  124_KI67.jpg      1664      1792   2981888
# 334   704_PGR.jpg      1568      1920   3010560
# ..            ...       ...       ...       ...
# 179   282_PGR.jpg      3472      7424  25776128
# 670    267_ER.jpg      3472      7424  25776128
# 403    371_ER.jpg      3472      7424  25776128
# 157    667_ER.jpg      3472      7424  25776128
# 195   203_PGR.jpg      3472      7424  25776128
#
# [1571 rows x 4 columns]
