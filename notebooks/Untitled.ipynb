# %%
import os
import pandas as pd

# %%
df = pd.read_csv('/home/phiwei/repos/pathology-cyclegan-stain-transformation/dataframes/df_acrobat_train_ihc_without_control_tissue.csv')
df
# Out:
#          slidename
# 0         205_KI67
# 1         532_KI67
# 2         673_KI67
# 3         471_KI67
# 4         736_KI67
# ..             ...
# 956      2_ER_test
# 957    16_KI67_val
# 958   154_PGR_test
# 959  263_KI67_test
# 960    43_PGR_test
#
# [961 rows x 1 columns]

# %%
path_base = '/mnt/ssd2tb/phiwei/6_test_inspected/'
l = list()
for filename in os.listdir(path_base):
    l.append(os.path.splitext(filename)[0])
df2 = pd.DataFrame()
df2['slidename'] = l
df2
# Out:
#          slidename
# 0      251_ER_test
# 1      12_PGR_test
# 2       25_PGR_val
# 3      234_ER_test
# 4      127_ER_test
# ..             ...
# 135      2_ER_test
# 136    16_KI67_val
# 137   154_PGR_test
# 138  263_KI67_test
# 139    43_PGR_test
#
# [140 rows x 1 columns]

# %%
pd.concat([df, df2]).reset_index(drop=True).to_csv('/home/phiwei/repos/pathology-cyclegan-stain-transformation/dataframes/df_acrobat_train_ihc_without_control_tissue.csv', index=False)
